# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram --preset anime
# Out:
# WARNING: Ignoring invalid distribution ~vidia-cudnn-cu12 (/usr/local/lib/python3.12/dist-packages)
# Requirement already satisfied: pygit2==1.15.1 in /usr/local/lib/python3.12/dist-packages (1.15.1)
# Requirement already satisfied: cffi>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from pygit2==1.15.1) (1.17.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.16.0->pygit2==1.15.1) (2.22)
# WARNING: Ignoring invalid distribution ~vidia-cudnn-cu12 (/usr/local/lib/python3.12/dist-packages)
# /content
# fatal: destination path 'Fooocus' already exists and is not an empty directory.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram', '--preset', 'anime']
# Python 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Version mismatch for anyio: Installed version 4.4.0 does not meet requirement anyio==4.8.0
# Installing requirements
# Couldn't install requirements.
# Command: "/usr/bin/python3" -m pip install -r "requirements_versions.txt" --prefer-binary
# Error code: 1
# stdout: Requirement already satisfied: accelerate==0.32.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 1)) (0.32.1)
# Requirement already satisfied: addict==2.4.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 2)) (2.4.0)
# Requirement already satisfied: aiofiles==23.2.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 3)) (23.2.1)
# Requirement already satisfied: aiohappyeyeballs==2.4.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 4)) (2.4.3)
# Requirement already satisfied: aiohttp==3.10.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 5)) (3.10.3)
# Requirement already satisfied: aiosignal==1.3.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 6)) (1.3.2)
# Requirement already satisfied: altair==5.4.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 7)) (5.4.0)
# Requirement already satisfied: annotated-doc==0.0.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 8)) (0.0.1)
# Requirement already satisfied: annotated-types==0.7.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 9)) (0.7.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 10)) (4.9.3)
# Collecting anyio==4.8.0 (from -r requirements_versions.txt (line 11))
#   Using cached anyio-4.8.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: async-timeout==4.0.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 12)) (4.0.3)
# Requirement already satisfied: attrs==24.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 13)) (24.2.0)
# Requirement already satisfied: certifi==2024.7.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 14)) (2024.7.4)
# Requirement already satisfied: cffi==1.17.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 15)) (1.17.0)
# Requirement already satisfied: charset-normalizer==3.3.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 16)) (3.3.2)
# Collecting click==8.2.0 (from -r requirements_versions.txt (line 17))
#   Using cached click-8.2.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: coloredlogs==15.0.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 18)) (15.0.1)
# Requirement already satisfied: contourpy==1.2.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 19)) (1.2.1)
# Requirement already satisfied: cuda-bindings==11.8.6 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 20)) (11.8.6)
# Requirement already satisfied: cuda-pathfinder==0.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 21)) (0.0.0)
# Requirement already satisfied: cycler==0.12.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 22)) (0.12.1)
# Requirement already satisfied: einops==0.8.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 23)) (0.8.0)
# Requirement already satisfied: exceptiongroup==1.2.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 24)) (1.2.2)
# Collecting fastapi==0.133.0 (from -r requirements_versions.txt (line 25))
#   Using cached fastapi-0.133.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: ffmpy==0.3.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 26)) (0.3.3)
# Requirement already satisfied: filelock==3.15.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 27)) (3.15.4)
# Requirement already satisfied: flatbuffers==24.3.25 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 28)) (24.3.25)
# Requirement already satisfied: fonttools==4.53.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 29)) (4.53.1)
# Requirement already satisfied: frozenlist==1.4.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 30)) (1.4.1)
# Collecting fsspec==2025.3.0 (from -r requirements_versions.txt (line 31))
#   Using cached fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: gradio==3.41.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 32)) (3.41.2)
# Collecting gradio_client==2.0 (from -r requirements_versions.txt (line 33))
#   Using cached gradio_client-2.0.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: groundingdino-py==0.4.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 34)) (0.4.0)
# Requirement already satisfied: h11==0.14.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 35)) (0.14.0)
# Requirement already satisfied: hf-xet==0.1.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 36)) (0.1.0)
# Requirement already satisfied: httpcore==1.0.5 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 37)) (1.0.5)
# Collecting httpx==0.28.1 (from -r requirements_versions.txt (line 38))
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting huggingface-hub==0.34.0 (from -r requirements_versions.txt (line 39))
#   Using cached huggingface_hub-0.34.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: humanfriendly==10.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 40)) (10.0)
# Collecting idna==3.18 (from -r requirements_versions.txt (line 41))
#   Using cached idna-3.18-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: imageio==2.34.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 42)) (2.34.2)
# Requirement already satisfied: importlib_metadata==9.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 43)) (9.0.0)
# Requirement already satisfied: importlib_resources==6.4.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 44)) (6.4.0)
# Requirement already satisfied: Jinja2==3.1.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 45)) (3.1.4)
# Requirement already satisfied: jsonschema==4.23.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 46)) (4.23.0)
# Requirement already satisfied: jsonschema-specifications==2023.12.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 47)) (2023.12.1)
# Requirement already satisfied: kiwisolver==1.4.5 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 48)) (1.4.5)
# Requirement already satisfied: lazy_loader==0.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 49)) (0.4)
# Requirement already satisfied: lightning-utilities==0.11.6 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 50)) (0.11.6)
# Requirement already satisfied: llvmlite==0.43.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 51)) (0.43.0)
# Requirement already satisfied: MarkupSafe==2.1.5 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 52)) (2.1.5)
# Requirement already satisfied: matplotlib==3.9.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 53)) (3.9.1)
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 54)) (1.3.0)
# Requirement already satisfied: multidict==6.0.5 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 55)) (6.0.5)
# Collecting narwhals==2 (from -r requirements_versions.txt (line 56))
#   Using cached narwhals-2.0.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: networkx==3.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 57)) (3.3)
# Requirement already satisfied: numba==0.60.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 58)) (0.60.0)
# Collecting numpy==2.0 (from -r requirements_versions.txt (line 59))
#   Using cached numpy-2.0.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 60)) (12.1.3.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 61)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 62)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 63)) (12.1.105)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from -r requirements_versions.txt (line 64))
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 65)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 66)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 67)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 68)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 69)) (2.20.5)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.9.86 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 70)) (12.9.86)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 71)) (12.1.105)
# Requirement already satisfied: omegaconf==2.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 72)) (2.3.0)
# Requirement already satisfied: onnxruntime==1.18.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 73)) (1.18.1)
# Requirement already satisfied: opencv-contrib-python-headless==4.10.0.84 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 74)) (4.10.0.84)
# Requirement already satisfied: opencv-python==4.10.0.84 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 75)) (4.10.0.84)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 76)) (4.10.0.84)
# Collecting orjson==3.11.5 (from -r requirements_versions.txt (line 77))
#   Using cached orjson-3.11.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Collecting packaging==24.2.0 (from -r requirements_versions.txt (line 78))
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pandas==2.2.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 79)) (2.2.2)
# Requirement already satisfied: pillow==10.4.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 80)) (10.4.0)
# Requirement already satisfied: platformdirs==4.2.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 81)) (4.2.2)
# Requirement already satisfied: pooch==1.8.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 82)) (1.8.2)
# Requirement already satisfied: propcache==0.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 83)) (0.0.0)
# Requirement already satisfied: protobuf==5.28.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 84)) (5.28.3)
# Requirement already satisfied: psutil==6.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 85)) (6.0.0)
# Requirement already satisfied: pycocotools==2.0.8 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 86)) (2.0.8)
# Requirement already satisfied: pycparser==2.22 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 87)) (2.22)
# Collecting pydantic==2.12.5 (from -r requirements_versions.txt (line 88))
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Requirement already satisfied: pydantic_core==2.20.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 89)) (2.20.1)
# Requirement already satisfied: pydub==0.25.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 90)) (0.25.1)
# Requirement already satisfied: pygit2==1.15.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 91)) (1.15.1)
# Requirement already satisfied: PyMatting==1.1.12 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 92)) (1.1.12)
# Requirement already satisfied: pyparsing==3.1.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 93)) (3.1.2)
# Requirement already satisfied: python-dateutil==2.9.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 94)) (2.9.0)
# Requirement already satisfied: python-multipart==0.0.9 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 95)) (0.0.9)
# Requirement already satisfied: pytorch-lightning==2.3.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 96)) (2.3.3)
# Requirement already satisfied: pytz==2024.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 97)) (2024.1)
# Collecting PyYAML==6.0.2 (from -r requirements_versions.txt (line 98))
#   Using cached PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: referencing==0.35.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 99)) (0.35.1)
# Requirement already satisfied: regex==2024.7.24 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 100)) (2024.7.24)
# Requirement already satisfied: rembg==2.0.57 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 101)) (2.0.57)
# Collecting requests==2.32.4 (from -r requirements_versions.txt (line 102))
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: rpds-py==0.20.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 103)) (0.20.0)
# Collecting safetensors==0.8.0 (from -r requirements_versions.txt (line 104))
#   Using cached safetensors-0.8.0-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: scikit-image==0.24.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 105)) (0.24.0)
# Requirement already satisfied: scipy==1.14.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 106)) (1.14.0)
# Requirement already satisfied: segment-anything==1.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 107)) (1.0)
# Requirement already satisfied: semantic-version==2.10.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 108)) (2.10.0)
# Requirement already satisfied: six==1.16.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 109)) (1.16.0)
# Requirement already satisfied: sniffio==1.3.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 110)) (1.3.1)
# Collecting starlette==1.0.1 (from -r requirements_versions.txt (line 111))
#   Using cached starlette-1.0.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: supervision==0.6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 112)) (0.6.0)
# Requirement already satisfied: sympy==1.13.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 113)) (1.13.2)
# Requirement already satisfied: tifffile==2024.8.10 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 114)) (2024.8.10)
# Requirement already satisfied: timm==1.0.7 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 115)) (1.0.7)
# Requirement already satisfied: tokenizers==0.19.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 116)) (0.19.1)
# Requirement already satisfied: tomli==2.0.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 117)) (2.0.1)
# Requirement already satisfied: torch==2.4.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 118)) (2.4.0)
# Requirement already satisfied: torchmetrics==1.4.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 119)) (1.4.1)
# Requirement already satisfied: torchsde==0.2.6 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 120)) (0.2.6)
# Requirement already satisfied: torchvision==0.19.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 121)) (0.19.0)
# Collecting tqdm==4.67 (from -r requirements_versions.txt (line 122))
#   Using cached tqdm-4.67.0-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: trampoline==0.1.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 123)) (0.1.2)
# Requirement already satisfied: transformers==4.42.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 124)) (4.42.4)
# Requirement already satisfied: triton==3.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 125)) (3.0.0)
# Requirement already satisfied: typing-inspection==0.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 126)) (0.0.0)
# Collecting typing_extensions==4.14 (from -r requirements_versions.txt (line 127))
#   Using cached typing_extensions-4.14.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: tzdata==2024.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 128)) (2024.1)
# Requirement already satisfied: urllib3==1.26.19 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 129)) (1.26.19)
# Collecting uvicorn==0.34 (from -r requirements_versions.txt (line 130))
#   Using cached uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting websockets==15.0.1 (from -r requirements_versions.txt (line 131))
#   Using cached websockets-15.0.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: yapf==0.40.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 132)) (0.40.2)
# Requirement already satisfied: yarl==1.9.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 133)) (1.9.4)
# Requirement already satisfied: zipp==3.23.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 134)) (3.23.1)
# INFO: pip is looking at multiple versions of accelerate to determine which version is compatible with other requirements. This could take a while.
#
# The conflict is caused by:
#     The user requested numpy==2.0
#     accelerate 0.32.1 depends on numpy<2.0.0 and >=1.17
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip to attempt to solve the dependency conflict
#
#
# stderr: WARNING: Ignoring invalid distribution ~vidia-cudnn-cu12 (/usr/local/lib/python3.12/dist-packages)
# ERROR: Cannot install accelerate==0.32.1 and numpy==2.0 because these package versions have conflicting dependencies.
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts
#
# CMD Failed requirements: install -r "requirements_versions.txt"
# Loaded preset: /content/Fooocus/presets/anime.json
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Total VRAM 14913 MB, total RAM 12976 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# Running on local URL:  http://127.0.0.1:7865
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# model_type EPS
# UNet ADM Dimension 2816
# Running on public URL: https://c2202277dd98572398.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.text_projection', 'cond_stage_model.clip_l.logit_scale'}
# left over keys: dict_keys(['cond_stage_model.clip_l.transformer.text_model.embeddings.position_ids'])
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# Base model loaded: /content/Fooocus/models/checkpoints/animaPencilXL_v500.safetensors
# VAE loaded: None
# Request to load LoRAs [] for model [/content/Fooocus/models/checkpoints/animaPencilXL_v500.safetensors].
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.62 seconds
# 2026-07-24 19:37:38.555847: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Started worker with PID 9707
# App started successful. Use the app with http://127.0.0.1:7865/ or 127.0.0.1:7865 or https://c2202277dd98572398.gradio.live
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 3313790987920599698
# [Parameters] CFG = 6
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Request to load LoRAs [('AetherIL-09.safetensors', 1.0)] for model [/content/Fooocus/models/checkpoints/animaPencilXL_v500.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/AetherIL-09.safetensors] for UNet [/content/Fooocus/models/checkpoints/animaPencilXL_v500.safetensors] with 788 keys at weight 1.0.
# Loaded LoRA [/content/Fooocus/models/loras/AetherIL-09.safetensors] for CLIP [/content/Fooocus/models/checkpoints/animaPencilXL_v500.safetensors] with 88 keys at weight 1.0.
# Requested to load SDXLClipModel
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 1.75 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] 1girl, aether, huge breasts, full body, intricate, highly detailed, wonderful, delicate, expressive, symmetry, sharp focus, beautiful, enhanced quality, elegant, creative, innocent, amazing, attractive, aesthetic, gorgeous, thought worthy, dramatic, joyful, epic, stunning, background, illuminated, breathtaking, scenic, great silent, pure, peaceful, perfect
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] 1girl, aether, huge breasts, full body, intricate, highly detailed, transparent, sharp focus, warm light, dramatic, majestic, expressive, frank romantic, thought, cinematic, artistic, background, beautiful, perfect, quiet, pristine, shiny, advanced, cute, cool, creative, passionate, amazing, charming, confident, pretty, attractive, iconic, best
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.15 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1344, 768)
# Preparation time: 5.80 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.30 seconds
#  40% 12/30 [00:11<00:17,  1.04it/s]
# User stopped
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 12.93 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 18.76 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.81 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 7174198461098890055
# [Parameters] CFG = 6
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] aether, 1girl, hair between eyes, braid, midriff, short sleeves, black gloves, single braid, cape, black pants, looking at viewer, huge breasts. full body, intricate, highly detailed, beautiful, delicate, sharp focus, expressive, charismatic, extremely inspirational, attractive, smart, luxury, dramatic background, designed, rich deep colors
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] aether, 1girl, hair between eyes, braid, midriff, short sleeves, black gloves, single braid, cape, black pants, looking at viewer, huge breasts. full body, intricate, elegant, highly detailed, cinematic, bright colors, light, sharp focus, beautiful, enhanced quality, winning color, illuminated background, designed, rich deep vivid
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.17 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1344, 768)
# Preparation time: 1.42 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.20 seconds
#  93% 28/30 [00:24<00:01,  1.15it/s]
# User skipped
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
#  40% 12/30 [00:11<00:16,  1.07it/s]
# User stopped
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 36.68 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 38.12 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.87 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 6466210954731561110
# [Parameters] CFG = 6
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] score_9, score_8_up, score_7_up, score_6_up, score_5_up, score_4_up, masterpiece, ultra-detailed, high resolution, very detailed, fine detail, sharp focus, atmosphere, full bright cinematic light, glowing rich colors, highly complex, extremely beautiful, symmetry, clear, artistic
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] score_9, score_8_up, score_7_up, score_6_up, score_5_up, score_4_up, masterpiece, ultra-detailed, high resolution, very detailed, color, intricate, epic composition, atmosphere, highly detail, cinematic light, sharp focus, professional, winning, sunny, real, full background
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# warning, embedding:deep_negative_pony, does not exist, ignoring
# warning, embedding:deep_negative_pony, does not exist, ignoring
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1344, 768)
# Preparation time: 1.46 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.04 seconds
#  83% 25/30 [00:23<00:04,  1.05it/s]
# User skipped
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
#  40% 12/30 [00:12<00:18,  1.01s/it]
# User stopped
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 37.05 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 38.53 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.88 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 5020066898850622728
# [Parameters] CFG = 6
# [Fooocus] Downloading control models ...
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/clip_vision_vit_h.safetensors" to /content/Fooocus/models/clip_vision/clip_vision_vit_h.safetensors
#
# 100% 1.84G/1.84G [00:26<00:00, 75.4MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_ip_negative.safetensors" to /content/Fooocus/models/controlnet/fooocus_ip_negative.safetensors
#
# 100% 64.1k/64.1k [00:00<00:00, 204kB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/ip-adapter-plus_sdxl_vit-h.bin" to /content/Fooocus/models/controlnet/ip-adapter-plus_sdxl_vit-h.bin
#
# 100% 967M/967M [00:20<00:00, 49.3MB/s]
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] aether, 1girl, male focus, earrings, jewelry, solo, hair between eyes, white scarf, looking at viewer, scarf, single earring, simple background, short sleeves, upper body, pout, braid, medium breasts full body, attractive, delicate, calm, charming, intricate, highly detailed, extremely lush, divine holy, elegant, sharp
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] aether, 1girl, male focus, earrings, jewelry, solo, hair between eyes, white scarf, looking at viewer, scarf, single earring, simple background, short sleeves, upper body, pout, braid, medium breasts full body, attractive, delicate, beautiful, intricate, highly detailed, elegant, sacred light, sharp color, epic, pristine
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Image processing ...
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.26 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.61 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.33 seconds
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1344, 768)
# Preparation time: 63.14 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.71 seconds
#  27% 8/30 [00:07<00:20,  1.07it/s]
# User skipped
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
#  27% 8/30 [00:07<00:20,  1.05it/s]
# User stopped
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 16.87 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 80.03 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.92 seconds

# %%
# !pip uninstall -y protobuf
# !pip install --no-cache-dir protobuf==5.28.3
# Out:
# Found existing installation: protobuf 5.28.0rc2
# Uninstalling protobuf-5.28.0rc2:
#   Successfully uninstalled protobuf-5.28.0rc2
# WARNING: Ignoring invalid distribution ~vidia-cudnn-cu12 (/usr/local/lib/python3.12/dist-packages)
# Collecting protobuf==5.28.3
#   Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 80.9 MB/s eta 0:00:00
# WARNING: Ignoring invalid distribution ~vidia-cudnn-cu12 (/usr/local/lib/python3.12/dist-packages)
# Installing collected packages: protobuf
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dataproc-spark-connect 1.1.0 requires tqdm>=4.67, but you have tqdm 4.66.4 which is incompatible.
# dataproc-spark-connect 1.1.0 requires websockets>=14.0, but you have websockets 11.0.3 which is incompatible.
# google-cloud-bigquery 3.42.2 requires packaging>=24.2.0, but you have packaging 24.1 which is incompatible.
# bigquery-magics 0.14.0 requires packaging>=24.2.0, but you have packaging 24.1 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 5.28.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.6.1 which is incompatible.
# firebase-admin 6.9.0 requires httpx[http2]==0.28.1, but you have httpx 0.27.0 which is incompatible.
# wandb 0.28.0 requires click>=8.2.0, but you have click 8.1.7 which is incompatible.
# yfinance 0.2.66 requires websockets>=13.0, but you have websockets 11.0.3 which is incompatible.
# Successfully installed protobuf-5.28.3

# %%
# !pip uninstall -y cupy cupy-cuda12x
# !pip install --force-reinstall numpy==1.26.4
# Out:
# WARNING: Skipping cupy as it is not installed.
# Found existing installation: cupy-cuda12x 14.0.1
# Uninstalling cupy-cuda12x-14.0.1:
#   Successfully uninstalled cupy-cuda12x-14.0.1
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cuml-cu12 26.2.0 requires cupy-cuda12x>=13.6.0, which is not installed.
# cudf-cu12 26.2.1 requires cupy-cuda12x>=13.6.0, which is not installed.
# nx-cugraph-cu12 26.2.0 requires cupy-cuda12x>=13.6.0, which is not installed.
# dask-cudf-cu12 26.2.1 requires cupy-cuda12x>=13.6.0, which is not installed.
# pylibcugraph-cu12 26.2.0 requires cupy-cuda12x>=13.6.0, which is not installed.
# cucim-cu12 26.2.0 requires cupy-cuda12x>=13.6.0, which is not installed.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# access 1.1.10.post3 requires scipy>=1.14.1, but you have scipy 1.14.0 which is incompatible.
# diffusers 0.39.0 requires safetensors>=0.8.0, but you have safetensors 0.4.3 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# db-dtypes 1.7.1 requires packaging>=24.2.0, but you have packaging 24.1 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires tqdm>=4.67, but you have tqdm 4.66.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# yfinance 0.2.66 requires websockets>=13.0, but you have websockets 11.0.3 which is incompatible.
# shap 0.52.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4
